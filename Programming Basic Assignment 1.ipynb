# %% [markdown]
# # 1. Write a Python program to print "Hello Python"?

# %%
mytext = "Hello Python"
print(mytext)
# Out:
# Hello Python

# %% [markdown]
# # 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = 10
b = 20
print("Addition of a and b is ", a+b)
print("Division of a and b is ", a/b)
# Out:
# Addition of a and b is  30
# Division of a and b is  0.5

# %% [markdown]
# # 3. Write a Python program to find the area of a triangle?

# %%
g_height = float(input("Enter height  "))
g_base = float(input("Enter base  "))
print('\nFormula is 1/2*base*height\n')
area_triangle = 1/2*g_height*g_base
print("The Area of Triangle is ",int(area_triangle))
# Out:
# Enter height  10
# Enter base  20
#
# Formula is 1/2*base*height
#
# The Area of Triangle is  100

# %% [markdown]
# # 3. Write a Python program to find the area of a triangle?

# %%
print("\n The Area of Triangle Another formula is (s*(s-a)*(s-b)*(s-c))-1/2 \n")
a = float(input('Enter first side: ')) 
b = float(input('Enter second side: '))  
c = float(input('Enter third side: '))  

# calculate the semi-perimeter  
s = (a + b + c) / 2  

# calculate the area  
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5  

print("The Area of triangle is ", area)
# Out:
#  The Area of Triangle Another formula is (s*(s-a)*(s-b)*(s-c))-1/2
#
# Enter first side: 20
# Enter second side: 20
# Enter third side: 10
# The Area of triangle is  96.82458365518542

# %% [markdown]
# # 4. Write a Python program to swap two variables?

# %%
a = 10
b = 20
print("A is ",a)
print("B is ",b)
print("Swapping With Using Temporary Variable\n")
c = a
a = b
b = c
print("After swapping, A is ",a,"B is ", b,"\n")
print("Swapping Without Using Temporary Variable \n")
a,b = b,a
print("After swapping, A is ",a,"B is ", b)
# Out:
# A is  10
# B is  20
# Swapping With Using Temporary Variable
#
# After swapping, A is  20 B is  10
#
# Swapping Without Using Temporary Variable
#
# After swapping, A is  10 B is  20

# %% [markdown]
# # 5. Write a Python program to generate a random number?

# %%
import random
# Generate interger random number
print('Generate interger random number',random.randint(10,12))
#  Generate floating random number
print('Generate floating rando number between 0 and 1',random.random())
# Generate floating random number
print('Generate floating rando number for given interval',random.uniform(3,7))
# Generate interger random number
print('Generate floating rando number for given range of interval',random.randrange(3,30,2))
# Out:
# Generate interger random number 10
# Generate floating rando number between 0 and 1 0.39351175559032836
# Generate floating rando number for given interval 3.4737801478803347
# Generate floating rando number for given range of interval 23
