# %% [markdown]
# # 7.What should the values of the following two terms be?
# ## 'spam' + 'spamspam'
# ## 'spam' * 3

# %%
print('spam'+'spamspam')
print('spam'*3)
# Out:
# spamspamspam
# spamspamspam

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# ### &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %% [markdown]
# #### Error is due to int is not allowed in concatenation, so we need to type cast int to str like below

# %%
'I have eaten '+str(99)+' burritos'
# Out:
# 'I have eaten 99 burritos'

# %% [markdown]
# # 6. After running the following code, what does the variable bacon contain?
# ### bacon = 22
# ### bacon + 1

# %% [markdown]
# #### only during executing bacon is added to 1, it won't change the original varibable
# #### bacon variable still holds value as 22

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %%
bacon
# Out:
# 22

# %% [markdown]
# # 8. Why is eggs a valid variable name while 100 is invalid?
# #### As per python rule, varibale name cannot begin with number

# %% [markdown]
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
int()
str()
float()
# Out:
# 0.0

# %% [markdown]
# # 3. Describe three different data types.
#
# #### integer, string and floting point are the three different data types

# %% [markdown]
# # 2.What is the difference between string and variable?
#
# #### variable is a name which holds value and it allocates a memory space, whereas value is a value which is assigned to variable
#
# #### python  -- variable
# #### 'python' -- string

# %% [markdown]
# # 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# ### * -- operator
# ### 'hello' -- value
# ### -87.8 -- value
# ### -  -- operator
# ### / -- oprator
# ### + -- operator
# ### 6 -- value

# %% [markdown]
# # 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# #### An expression is an instruction that combines values and operators and always evaluates down to a single value.

# %% [markdown]
# # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# #### Expressions represent something, like a number, a string, or an instance of a class. Any value is an expression!
#
# #### Anything that does something is a statement. Any assignment to a variable or function call is a statement. Any value contained in that statement in an expression.
