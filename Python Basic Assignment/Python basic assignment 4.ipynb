# %% [markdown]
# # 1. What exactly is []?

# %% [raw]
# [] notation to define empty list

# %% [markdown]
# # 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %% [raw]
# spam.insert(2,'hello')

# %% [markdown]
# # 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %% [raw]
# spam = ['a','b','c','d']
#
# then value will be 'd'

# %% [markdown]
# # 4. What is the value of spam[-1]?

# %% [raw]
# spam = ['a','b','c','d']
# 'd'

# %% [markdown]
# # 5. What is the value of spam[:2]?

# %% [raw]
# spam = ['a','b','c','d']
# output is : 'a','b','c'

# %% [markdown]
# # 6. What is the value of bacon.index(&#39;cat&#39;)?

# %% [raw]
# bacon = [3.14,'cat',11,'cat',True]
# bacon.index('cat') is 1

# %% [markdown]
# # 7. How does bacon.append(99) change the look of the list value in bacon?

# %% [raw]
# bacon = [3.14,'cat',11,'cat',True]
# bacon.append(99)
# then list will be changed to bacon = [3.14,'cat',11,'cat',True,99]

# %% [markdown]
# # 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %% [raw]
# remove method if executed only once then bacon will be updated as [3.14, 11, 'cat', True, 99]

# %% [markdown]
# # 9. What are the list concatenation and list replication operators?

# %% [raw]
# list concatenation is +
# list reoplication is *

# %% [markdown]
# # 10. What is difference between the list methods append() and insert()?

# %% [raw]
# in list append used to add values to the end of list
# in list insert has two parameters one is index position in which plave value needs to be inserted and another is value or object

# %% [markdown]
# # 11. What are the two methods for removing items from a list?

# %% [raw]
# method remove and pop

# %% [markdown]
# # 12. Describe how list values and string values are identical.

# %% [raw]
# both list and string are ordered collection of elements except list can be homogeneous or hetrogeneous collection whereas string can have only ont type is string

# %% [markdown]
# # 13. What&#39;s the difference between tuples and lists?

# %% [raw]
# list are tuples are ordered collection of elements which can be combination of any type , list is mutable whereas tuple are immutable, once elements are added to tuple it cannot be changed
# list are created using []
# tuple are created using ()

# %% [markdown]
# # 14. How do you type a tuple value that only contains the integer 42?

# %% [raw]
# (42,)

# %% [markdown]
# # 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %% [raw]
# tuple()
# list()
# respectively

# %% [markdown]
# # 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they contain?

# %% [raw]
# it has reference to list

# %% [markdown]
# # 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [raw]
# copy.copy() is shallow copy function when referenced varibale is changed the original value also changes due to both variable shares same memory space
# copy.deepcopy() is deep copy method which will duplicate the list and creates a separate memory space
