# %% [markdown]
# # 1. What does an empty dictionary&#39;s code look like?

# %% [raw]
# with two curly brackets {}

# %% [markdown]
# # 2. What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?

# %% [raw]
# {'foo':42}

# %% [markdown]
# # 3. What is the most significant distinction between a dictionary and a list?

# %% [raw]
# list is ordered collection of elements, elements can be accessed using index position
# dictionary is unordered collection of KEY:VALUE pairs, values can be accessed using KEYS

# %% [markdown]
# # 4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %% [raw]
# you will get KeyError

# %% [markdown]
# # 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and &#39;cat&#39; in spam.keys()?

# %% [raw]
# There is no difference as both expression checks for KEYS, if key is present then corresponding value will be derived

# %% [markdown]
# # 6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and &#39;cat&#39; in spam.values()?

# %% [raw]
# 'cat' in spam -> this will check is cat is key in spam
# 'cat' in spam.values() -> this will check is cat is value in spam

# %% [markdown]
# # 7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;]
# = &#39;black&#39;

# %% [raw]
# spam.setdefault('color','black')

# %% [markdown]
# # 8. How do you &quot;pretty print&quot; dictionary values using which module and function?

# %% [raw]
# pprint.pprint()
